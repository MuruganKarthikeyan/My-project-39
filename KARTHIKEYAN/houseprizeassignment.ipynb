# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from xgboost import XGBRFRegressor, XGBRegressor
from sklearn.metrics import mean_squared_error, mean_absolute_error, mean_absolute_percentage_error, r2_score

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
        
import warnings
warnings.filterwarnings("ignore")

# %%
path = "/content/drive/MyDrive/House Price India.csv"

# %%
df = pd.read_csv(path)

# %%
df.head(14622)
# Out:
#                id   Date  number of bedrooms  number of bathrooms  \
# 0      6762810145  42491                   5                 2.50
# 1      6762810635  42491                   4                 2.50
# 2      6762810998  42491                   5                 2.75
# 3      6762812605  42491                   4                 2.50
# 4      6762812919  42491                   3                 2.00
# ...           ...    ...                 ...                  ...
# 14615  6762830250  42734                   2                 1.50
# 14616  6762830339  42734                   3                 2.00
# 14617  6762830618  42734                   2                 1.00
# 14618  6762830709  42734                   4                 1.00
# 14619  6762831463  42734                   3                 1.00
#
#        living area  lot area  number of floors  waterfront present  \
# 0             3650      9050               2.0                   0
# ...

# %%
# univarient of number of bedrooms
sns.countplot(data=df,x='number of bedrooms')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
# univarient of date
sns.countplot(data=df,x='Date')
# Out:
# <Axes: xlabel='Date', ylabel='count'>

# %%
# univarient of living area
sns.countplot(data=df,x='living area')
# Out:
# <Axes: xlabel='living area', ylabel='count'>

# %%
# univarient of Built Year
sns.countplot(data=df,x='Built Year')
# Out:
# <Axes: xlabel='Built Year', ylabel='count'>

# %%
# univarient of Number of schools nearby
sns.countplot(data=df,x='Number of schools nearby')
# Out:
# <Axes: xlabel='Number of schools nearby', ylabel='count'>

# %%
# bivarient of number of bedrooms and number of schools nearby
sns.countplot(data=df,x='number of bedrooms',hue='Number of schools nearby')
# Out:
# <Axes: xlabel='number of bedrooms', ylabel='count'>

# %%
# bivarient of Date and living area
sns.countplot(data=df,x='Date',hue='living area')
# Out:
# <Axes: xlabel='Date', ylabel='count'>

# %%
# bivarient of number of floors and condition of the house	
sns.countplot(data=df,x='number of floors',hue='condition of the house')
# Out:
# <Axes: xlabel='number of floors', ylabel='count'>

# %%
# multivarient
sns.heatmap(df.corr())
# Out:
# <Axes: >

# %%
# Descriptive statistics
df.describe()
# Out:
#                  id          Date  number of bedrooms  number of bathrooms  \
# count  1.462000e+04  14620.000000        14620.000000         14620.000000
# mean   6.762821e+09  42604.538646            3.379343             2.129583
# std    6.237575e+03     67.347991            0.938719             0.769934
# min    6.762810e+09  42491.000000            1.000000             0.500000
# 25%    6.762815e+09  42546.000000            3.000000             1.750000
# 50%    6.762821e+09  42600.000000            3.000000             2.250000
# 75%    6.762826e+09  42662.000000            4.000000             2.500000
# max    6.762832e+09  42734.000000           33.000000             8.000000
#
#         living area      lot area  number of floors  waterfront present  \
# count  14620.000000  1.462000e+04      14620.000000        14620.000000
# mean    2098.262996  1.509328e+04          1.502360            0.007661
# std      928.275721  3.791962e+04          0.540239            0.087193
# ...
